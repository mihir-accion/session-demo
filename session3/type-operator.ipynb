# %% [markdown]
# # Type Operators

# %% [markdown]
# **typeof** operator

# %%
const point = {
    x: 50,
    y: 100
}

type Point = typeof point

# %%
const MyArray = [
  { name: "Alice", age: 15 },
  { name: "Bob", age: 23 },
  { name: "Eve", age: 38 },
];
 
type Person = typeof MyArray[number];

type Age = typeof MyArray[number]["age"];

# %% [markdown]
# **keyof** operator

# %%
type P = keyof Point;
